# %% [markdown]
# project rock paper scissors game

# %%
import random

def get_player_choice():
  while True:
    player_choice = input("Enter your choice (rock/paper/scissors):").lower()
    if player_choice in ['rock','paper','scissors']:
       return player_choice
    else:
        print("invalid choice!please enter rock,paper, or scissors.")

def get_computer_choice():
    choices = ['rock','paper','scissor']
    computer_choice = random.choice(choices)
    return computer_choice

def determine_winner(player_choice,computer_choice):
  if player_choice == computer_choice:
    return "it's a tie!"
  elif (player_choice == 'rock' and computer_choice == 'scissors') or (player_choice == 'paper' and computer_choice == 'rock') or (player_choice == 'scissors' and computer_choice == 'paper'):
    return 'you win!'
  else:
    return"Computer wins!"
def score(result,player_score,computer_score):
  if result =="you win!":
    player_score +=1
    print("You win!")

  elif result == "Computer wins!":
    computer_score += 1
    print("Computer wins!")

  else:
    print("It's a tie!")

  print(f"player score : {player_score}/computer score : {computer_score}")
  return player_score,computer_score

def play_game():
  computer_score = 0
  player_score = 0

  print("welcome to the game of rock,paper,scissors game!")
  while True:
     player_choice = get_player_choice()
     computer_choice = get_computer_choice()
     print(f"you chose : {player_choice}")
     print(f"computer chose : {computer_choice}")
     result = determine_winner(player_choice,computer_choice)
     player_score, computer_score = score(result, player_score, computer_score)
     play_again = input("Do you want to play again? (yes/no):")
     if play_again.lower() != 'yes':
      print("final scores")
      print(f"player score : {player_score}/computer score : {computer_score}")
      print("Thanks for playing!")
      break

#start the game
play_game()
# Out:
# welcome to the game of rock,paper,scissors game!
# Enter your choice (rock/paper/scissors):rock
# you chose : rock
# computer chose : rock
# It's a tie!
# player score : 0/computer score : 0
# Do you want to play again? (yes/no):yes
# Enter your choice (rock/paper/scissors):paper
# you chose : paper
# computer chose : scissor
# Computer wins!
# player score : 0/computer score : 1
# Do you want to play again? (yes/no):yes
# Enter your choice (rock/paper/scissors):scissors
# you chose : scissors
# computer chose : rock
# Computer wins!
# player score : 0/computer score : 2
# Do you want to play again? (yes/no):no
# final scores
# player score : 0/computer score : 2
# Thanks for playing!
